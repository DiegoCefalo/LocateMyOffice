# %% [markdown]
# # The office

# %% [markdown]
# ![stonks](img/stonks.jpg)

# %% [markdown]
#     He sido invocado para adivinar la localización de la nueva oficina de la empresa, y mediante mi brujeria y poderes cósmicos he sido capaz de determinar donde la vamos a poner.

# %%
import src.funcioncitas as sr
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#     Primero decidimos tres posibles lugares a boleo.

# %%
los_angeles = [34.0522,-118.2437]
madrid = [40.4168,-3.7038]
londres = [51.5074,-0.1278]

# %% [markdown]
#     Luego hacemos una llamada a la api de foursquare que nos permite saber todos los locales que nos interesan en un radio de 10 km. Luego obtenemos la respuesta en un chorizo de json, razon por la cual hay que organizarlo y quedarnos solo con lo que nos interesa para guardarlo en el ordenador y luego subirlo a una base de datos. Posteriormente, seguimos teniendo un chorizo de información, por ende, para su comodida, me he tomado la molestia de graficarlo. Y todo ese proceso queda empaquetado en un humilde regalo llamado "El mapamático", además guarda el html del mapa.

# %% [markdown]
# ## Los Ángeles

# %% [markdown]
#     Despues de graficarlo nos damos cuenta de que parece que se nos cayó una bolsa de M&M's. Pero no se preocupen que le he agregado una leyenda que nos permite ver solamente los locales que queremos.

# %%
sr.mapamatico(los_angeles,1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
#     Ahora viene el momento de determinar cuanto vale esta localización. Para eso he creado "El puntajilizador" que en base a ciertos criterios, nos permite pesar la cercanía y la importancia de los locales que queremos alrededor (el máximo son 100 puntos). Los criterios son:
# - Queremos tener restaurantes veganos cerca porque el jefe es vegano y si lo mantengo contento me da un ascenso. (40% de peso)
# - Puesto a que este trabajo demanda más que un recién nacido, la peña necesita donde recrearse al salir, por ende, buscamos bares. (30%)
# - Hay que tomar encuenta los  Starbucks porque sin café los ejecutivos no sirven. (10% de peso)
# - Aparentemente nuestros empleados se reproducen como conejos, por lo que requieren de guarderias para cuidar a los niños. (10% de peso)
# - Finalmente, al conserje le gusta el basket y es muy majo, asi que le toca un estadio cerca. (10% de peso)

# %%
sr.puntajilizador('LA',los_angeles)
# Out:
# /mnt/c/Users/diego/company_location/src/funcioncitas.py:115: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   media = df.sort_values('distancia(km)').head(3).mean()['distancia(km)']
# 92.55712591283188

# %% [markdown]
#     Bueno, era de esperarse, Los Ángeles tiene de todo.

# %% [markdown]
# ## Londres

# %% [markdown]
#     Hacemos exactamente lo mismo para Londres

# %%
sr.mapamatico(londres,2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
sr.puntajilizador('Londres',londres)
# Out:
# 92.76101681651932

# %% [markdown]
#     Casi tanto como años tiene la reina 👑

# %% [markdown]
# ## Madrid

# %% [markdown]
#     Adivinaron, lo mismo para Madrid 🤓

# %%
sr.mapamatico(madrid,3)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
sr.puntajilizador('Madrid',madrid)
# Out:
# 94.9022700140491

# %% [markdown]
#     Ahhh pero a que no se lo esperaban, resulta que Madrid tiene de todo Y DEPASO cerca. Así que gana madrid. Fin

# %% [markdown]
# ## Grafiquito para los que no lo vieron

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.barplot(x = ['Los Ángeles', 'Londres', 'Madrid'], y=[92.55712591283188,92.76101681651932,94.9022700140491])
plt.ylim(91, 96)
fig.savefig("img/histograma.jpg", dpi=100)
